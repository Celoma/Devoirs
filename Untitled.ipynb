# %%
class Equation:
    """Classe permettant de résoudre des équations. Du degré 0 au deuxième degré
    """
    
    def __init__(self, a, b=0, c=0, degre=0):
        
        signe = []
        self.degre = degre
        
        if a < 0 : 
            signe.append(-1)
        else :
            signe.append(1)
            
        if b < 0 : 
            signe.append(-1)
        else :
            signe.append(1)
            
        if c < 0 : 
            signe.append(-1)
        else :
            signe.append(1)

        self.signe = signe
        self.a = abs(a)
        self.b = abs(b)
        self.c = abs(c)
        
    def resoudre(self, resultat = 0):
        if self.degre == 0:
            return f"L'équation {self.a} = {resultat} n'est pas résoluble"
        if self.degre == 1:
            return f"L'équation {self.a * self.signe[0]}x {self.b * self.signe[1]} = {resultat} est résuluble par x = {reponse}"
    
    def __str__(self):
        if self.degre == 0:
            return f"{self.a}"
        if self.degre == 1:
            return f"{self.a * self.signe[0]}x {self.b * self.signe[1]}"
        if self.degre == 2:
            return f"{self.a * self.signe[0]}x**2 {self.b * self.signe[1]}x {self.c* self.signe[2]}"
    
    def __repr__(self):
        if self.degre == 0:
            return f"{self.a}"
        if self.degre == 1:
            return f"{self.a * self.signe[0]}x {self.b * self.signe[1]}"
        if self.degre == 2:
            return f"{self.a * self.signe[0]}x**2 {self.b * self.signe[1]}x {self.c* self.signe[2]}"

# %%
Inconnu = Equation(7)

print(Inconnu)
Inconnu
# Out:
# 7
# 7

# %%
Inconnu.resoudre()
# Out:
# "L'équation 7 = 0 n'est pas résoluble"
